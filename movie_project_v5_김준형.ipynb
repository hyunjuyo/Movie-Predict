# %%
import numpy as np 
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import re
from ast import literal_eval
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

# %%
movie_data = pd.read_csv("set_movie.csv")
movie_df = pd.DataFrame(movie_data)
movie_df.head()
# Out:
#    Unnamed: 0    budget                                             genres  \
# 0           1   4000000  [{'id': 27, 'name': 'Horror'}, {'id': 18, 'nam...
# 1           8  35000000                      [{'id': 18, 'name': 'Drama'}]
# 2          37   2900000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 3          74  10500000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4         106  20000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#        id original_language          original_title  \
# 0   13310                sv  Låt den rätte komma in
# 1    9701                en           North Country
# 2  123109                en            No One Lives
# 3   20002                hi  Chandni Chowk To China
# 4   15092                en     Crank: High Voltage
#
#                                             overview  popularity release_date  \
# 0  Set in 1982 in the suburb of Blackeberg, Stock...    7.274237   2008-01-26
# 1  A fictionalized account of the first major suc...    8.781298   2005-02-12
# 2  A gang of ruthless highway killers kidnap a we...    7.202832   2013-03-09
# 3  Based in Delhi's Chandni Chowk, orphaned Sidhu...    1.970481   2009-01-16
# 4  Chelios faces a Chinese mobster who has stolen...   10.044642   2009-04-16
#
#       revenue  runtime    status                   title  vote_average  \
# 0  10785801.0    115.0  Released    Let the Right One In           7.5
# 1  25224242.0    126.0  Released           North Country           6.9
# 2     74918.0     86.0  Released            No One Lives           5.5
# 3   9400000.0    149.0  Released  Chandni Chowk To China           5.3
# 4  34560577.0     96.0  Released     Crank: High Voltage           5.9
#
#    vote_count                                           keywords  \
# 0       997.0  ['female nudity', 'vampire', 'castration', 'bu...
# 1       127.0  ['rape', 'secret', 'minnesota', 'witness', 'mi...
# 2       173.0  ['suicide', 'male nudity', 'female nudity', 's...
# 3        13.0                           ['musical', 'bollywood']
# 4       878.0  ['female nudity', 'prostitute', 'horse race', ...
#
#                                                 cast  \
# 0  [{'cast_id': 1, 'character': 'Oskar', 'credit_...
# 1  [{'cast_id': 1, 'character': 'Josey Aimes', 'c...
# 2  [{'cast_id': 3, 'character': 'Driver', 'credit...
# 3  [{'cast_id': 10, 'character': 'Sidhu', 'credit...
# 4  [{'cast_id': 1, 'character': 'Chev Chelios', '...
#
#                                                 crew    year        WR
# 0  [{'credit_id': '52fe455a9251416c75053821', 'de...  2008.0  6.498874
# 1  [{'credit_id': '52fe451ec3a36847f80bd87b', 'de...  2005.0  6.263596
# 2  [{'credit_id': '52fe4a8dc3a368484e159f4b', 'de...  2013.0  6.211304
# 3  [{'credit_id': '52fe43d2c3a368484e00004d', 'de...  2009.0  6.239733
# 4  [{'credit_id': '52fe46389251416c7507138f', 'de...  2009.0  6.179846

# %%
movie_df.drop(columns=["status"],inplace=True)
movie_df.head()
# Out:
#    Unnamed: 0    budget                                             genres  \
# 0           1   4000000  [{'id': 27, 'name': 'Horror'}, {'id': 18, 'nam...
# 1           8  35000000                      [{'id': 18, 'name': 'Drama'}]
# 2          37   2900000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 3          74  10500000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4         106  20000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#        id original_language          original_title  \
# 0   13310                sv  Låt den rätte komma in
# 1    9701                en           North Country
# 2  123109                en            No One Lives
# 3   20002                hi  Chandni Chowk To China
# 4   15092                en     Crank: High Voltage
#
#                                             overview  popularity release_date  \
# 0  Set in 1982 in the suburb of Blackeberg, Stock...    7.274237   2008-01-26
# 1  A fictionalized account of the first major suc...    8.781298   2005-02-12
# 2  A gang of ruthless highway killers kidnap a we...    7.202832   2013-03-09
# 3  Based in Delhi's Chandni Chowk, orphaned Sidhu...    1.970481   2009-01-16
# 4  Chelios faces a Chinese mobster who has stolen...   10.044642   2009-04-16
#
#       revenue  runtime                   title  vote_average  vote_count  \
# 0  10785801.0    115.0    Let the Right One In           7.5       997.0
# 1  25224242.0    126.0           North Country           6.9       127.0
# 2     74918.0     86.0            No One Lives           5.5       173.0
# 3   9400000.0    149.0  Chandni Chowk To China           5.3        13.0
# 4  34560577.0     96.0     Crank: High Voltage           5.9       878.0
#
#                                             keywords  \
# 0  ['female nudity', 'vampire', 'castration', 'bu...
# 1  ['rape', 'secret', 'minnesota', 'witness', 'mi...
# 2  ['suicide', 'male nudity', 'female nudity', 's...
# 3                           ['musical', 'bollywood']
# 4  ['female nudity', 'prostitute', 'horse race', ...
#
#                                                 cast  \
# 0  [{'cast_id': 1, 'character': 'Oskar', 'credit_...
# 1  [{'cast_id': 1, 'character': 'Josey Aimes', 'c...
# 2  [{'cast_id': 3, 'character': 'Driver', 'credit...
# 3  [{'cast_id': 10, 'character': 'Sidhu', 'credit...
# 4  [{'cast_id': 1, 'character': 'Chev Chelios', '...
#
#                                                 crew    year        WR
# 0  [{'credit_id': '52fe455a9251416c75053821', 'de...  2008.0  6.498874
# 1  [{'credit_id': '52fe451ec3a36847f80bd87b', 'de...  2005.0  6.263596
# 2  [{'credit_id': '52fe4a8dc3a368484e159f4b', 'de...  2013.0  6.211304
# 3  [{'credit_id': '52fe43d2c3a368484e00004d', 'de...  2009.0  6.239733
# 4  [{'credit_id': '52fe46389251416c7507138f', 'de...  2009.0  6.179846

# %%
movie_df = movie_df.astype({"budget":"int"})
movie_df["release_date"] = pd.to_datetime(movie_df["release_date"])
movie_df = movie_df.astype({"year":"int"})

# %%
# 영향을 주지 않을
movie_df = movie_df.drop([movie_df.index[1188],movie_df.index[2353],movie_df.index[2175],movie_df.index[2398],movie_df.index[3038]])
movie_df.drop(columns=["original_title",'Unnamed: 0',"vote_count","vote_average","id","overview","title","keywords","crew","release_date"],inplace=True)
movie_df.head()
# Out:
#      budget                                             genres  \
# 0   4000000  [{'id': 27, 'name': 'Horror'}, {'id': 18, 'nam...
# 1  35000000                      [{'id': 18, 'name': 'Drama'}]
# 2   2900000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 3  10500000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4  20000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#   original_language  popularity     revenue  runtime  \
# 0                sv    7.274237  10785801.0    115.0
# 1                en    8.781298  25224242.0    126.0
# 2                en    7.202832     74918.0     86.0
# 3                hi    1.970481   9400000.0    149.0
# 4                en   10.044642  34560577.0     96.0
#
#                                                 cast    year        WR
# 0  [{'cast_id': 1, 'character': 'Oskar', 'credit_...  2008.0  6.498874
# 1  [{'cast_id': 1, 'character': 'Josey Aimes', 'c...  2005.0  6.263596
# 2  [{'cast_id': 3, 'character': 'Driver', 'credit...  2013.0  6.211304
# 3  [{'cast_id': 10, 'character': 'Sidhu', 'credit...  2009.0  6.239733
# 4  [{'cast_id': 1, 'character': 'Chev Chelios', '...  2009.0  6.179846

# %%
# 대표 배우 1명
movie_df["cast"] = movie_df["cast"].apply(literal_eval)
movie_df["cast_cnt"] = movie_df["cast"].apply(lambda x: len(x)) 
movie_df["cast"] = movie_df["cast"].apply(lambda x : [i["name"] for i in x] if isinstance(x, list) else [])
movie_df["cast"] = movie_df["cast"].apply(lambda x : x[:1])

# %%
for i in range(len(movie_df["cast"])):
    try:
         movie_df["cast"][i] = [re.sub(r'[^\w]', '_',re.sub(r'[^\w\s]', '', entry)) for entry in movie_df["cast"][i]]
    except:
        movie_df["cast"][i]  = ['']
# Out:
# C:\Users\alal8\AppData\Local\Temp/ipykernel_13192/3272636718.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df["cast"][i] = [re.sub(r'[^\w]', '_',re.sub(r'[^\w\s]', '', entry)) for entry in movie_df["cast"][i]]
# C:\Users\alal8\AppData\Local\Temp/ipykernel_13192/3272636718.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df["cast"][i]  = ['']

# %%
movie_df["genres"] = movie_df["genres"].fillna("[]").apply(literal_eval).apply(lambda x : [i["name"] for i in x] if isinstance(x, list) else [])
movie_df["genres"] = movie_df["genres"].apply(lambda x : x[:1])

# %%
movie_df.head()
# Out:
#      budget    genres original_language  popularity     revenue  runtime  \
# 0   4000000  [Horror]                sv    7.274237  10785801.0    115.0
# 1  35000000   [Drama]                en    8.781298  25224242.0    126.0
# 2   2900000  [Horror]                en    7.202832     74918.0     86.0
# 3  10500000  [Action]                hi    1.970481   9400000.0    149.0
# 4  20000000  [Action]                en   10.044642  34560577.0     96.0
#
#                 cast    year        WR  cast_cnt
# 0   [Kåre_Hedebrant]  2008.0  6.498874        15
# 1  [Charlize_Theron]  2005.0  6.263596        17
# 2       [Luke_Evans]  2013.0  6.211304        14
# 3     [Akshay_Kumar]  2009.0  6.239733         9
# 4    [Jason_Statham]  2009.0  6.179846        96

# %%
movie_df = movie_df.astype({"genres":"str"})
movie_df = movie_df.astype({"cast":"str"})

# %%
movie_dum= pd.get_dummies(movie_df)

# %%
X = movie_dum.drop(columns=["WR"]).values
y = movie_dum["WR"].values

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.3, random_state=13)

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred_tr = reg.predict(X_train)
pred_test = reg.predict(X_test)
rmse_tr = (np.sqrt(mean_squared_error(y_train, pred_tr)))
rmse_test = (np.sqrt(mean_squared_error(y_test, pred_test)))

print("RMSE of Train Data : ", rmse_tr)
print("RMSE of Test Data : ", rmse_test)
# Out:
# RMSE of Train Data :  0.11929921693692477
# RMSE of Test Data :  29.627403261292084

# %%
X = movie_dum.drop(columns=["WR","year"]).values
y = movie_dum["WR"].values

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.3, random_state=13)

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred_tr = reg.predict(X_train)
pred_test = reg.predict(X_test)
rmse_tr = (np.sqrt(mean_squared_error(y_train, pred_tr)))
rmse_test = (np.sqrt(mean_squared_error(y_test, pred_test)))

print("RMSE of Train Data : ", rmse_tr)
print("RMSE of Test Data : ", rmse_test)
# Out:
# RMSE of Train Data :  0.11973647421963136
# RMSE of Test Data :  1.6990542280840704

# %%
X = movie_dum.drop(columns=["WR",]).values
y = movie_dum["WR"].values

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.3, random_state=13)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13192/907820020.py in <module>
# ----> 1 X = movie_dum.drop(columns=["WR","original_language"]).values
#       2 y = movie_dum["WR"].values
#       3
#       4 X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.3, random_state=13)
#
# ~\miniconda3\envs\ds_study\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\miniconda3\envs\ds_study\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\miniconda3\envs\ds_study\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\miniconda3\envs\ds_study\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\miniconda3\envs\ds_study\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['original_language'] not found in axis"

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred_tr = reg.predict(X_train)
pred_test = reg.predict(X_test)
rmse_tr = (np.sqrt(mean_squared_error(y_train, pred_tr)))
rmse_test = (np.sqrt(mean_squared_error(y_test, pred_test)))

print("RMSE of Train Data : ", rmse_tr)
print("RMSE of Test Data : ", rmse_test)
# Out:
# RMSE of Train Data :  0.11973647421963136
# RMSE of Test Data :  1.6990542280840704
